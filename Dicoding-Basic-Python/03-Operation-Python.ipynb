# %% [markdown]
# # Operation in Python
#
# ## Transformasi Angka, Karakter, dan String

# %%
x=1
print(print(t)ype(x))
print(str(x).zfill(5))

# %%
p = 'Hello world!'
p = p.upper()
p

# %%
p = p.lower()
p

# %%
feeling = input('How are you?')
if feeling.lower() == 'great':
    print('I feel great too.')
else:
    print('I hope the rest of your day is good.')

# %%
print('Hello'.upper())
print('Hello'.upper().lower())
print('Hello'.upper().lower().upper())
print('HELLO'.lower())
print('HELLO'.lower().islower())
print('HELLO'.lower().upper().isupper())

# %% [markdown]
# ### Check the string
#
# - isalpha() mengembalikan True jika string berisi hanya huruf dan tidak kosong.
# - isalnum() mengembalikan True jika string berisi hanya huruf atau angka, dan tidak kosong.
# - isdecimal() mengembalikan True jika string berisi hanya angka/numerik dan tidak kosong.
# - isspace() mengembalikan True jika string berisi hanya spasi, tab, newline, atau whitespaces lainnya dan tidak kosong.
# - istitle() mengembalikan True jika string berisi kata yang diawali huruf kapital dan dilanjutkan dengan huruf kecil seterusnya.

# %%
while True:
    print('Enter your age:')
    age = input()
    if age.isdecimal():
        break
    print('Please enter a number for your age.')
while True:
    print('Select a new password (letters and numbers only):')
    password = input()
    if password.isalnum():
        break
    print('Passwords can only have letters and numbers.')

print('Your Age is', age)
print('Youd Password is',password)

# %% [markdown]
# ### Metode startswith() dan endswith() dari String

# %%
'Hello world!'.endswith('world!')
'abc123'.startswith('abcdef')

# %% [markdown]
# ### Metode Join() dan Split() pada String

# %%
print(' '.join(['My', 'name', 'is', 'Simon']))
print('My name is Simon'.split())
print('MyABCnameABCisABCSimon'.split('ABC'))

a = '''Dear Alice,
How have you been? I am fine.
There is a container in the fridge
that is labeled "Milk Experiment".
Please do not drink it.
Sincerely,
Bob'''
a.split('\n')

# %% [markdown]
# ### Metode Teks Rata Tengah/Kanan/Kiri

# %%
#rjust, ljust, center
print('hello'.rjust(9, '-')) #----hello
print('hello'.ljust(9, '*')) #hello****
print('hello'.center(9, '*')) #**hello**

# %% [markdown]
# ### Metode Menhapus Whitespace

# %%
#strip,lstrip,rstrip
print('hello1111'.strip('1')) #hello
print('hello1111'.rstrip('1')) #hello
print('hello1111'.ltrip('1')) #hello1111

# %% [markdown]
# ### Mengganti string/substring dengan replace()

# %%
#replace
print('good morning'.replace('morning', 'afternoon')) #good afternoon

# %% [markdown]
# ## Operasi pada urutan (sequences: List, Set, String)

# %%
l = [1,2,3,3,4,4,4,4,5,6]
s = set(l)
x = "Hello, World"
 
print(l)
print(len(l))
 
print(s)
print(len(s))
 
print(x)
print(len(x))

# %%
[1, 2, 3] + ['A', 'B', 'C']

# %%
['X', 'Y', 'Z'] * 3

# %%
spam = [1, 2, 3]
spam = spam + ['A', 'B', 'C']
spam

# %%
arr = [0]*10
len(arr)
arr

# %%
for i in range(9):
    print(i)

# %%
for i in range(3, 9):
    print(i)

# %%
[_ for _ in range(1, 9, 2)]

# %%
spam = ['hello', 'hi', 'howdy', 'heyas']
print('cat' in spam)
print('howdy' not in spam)

# %% [markdown]
# ### Memberikan Nilai pada variabel sekaligus

# %%
cat = ['fat', 'orange', 'loud'] # From List
size, color, disposition = cat
cat = ('fat', 'orange', 'loud')  # From Tuple
size, color, disposition = cat

# %%
# untuk menukar nilai variabel
a, b = 'Alice', 'Bob'
a, b = b, a
print(a)
print(b)

# %% [markdown]
# ### Sort

# %%
x = [2, 5, 3.14, 1, -7]
x.sort()
x

# %%
y = ['ants', 'cats', 'dogs', 'badgers', 'elephants']
y.sort()
y

# %%
y.sort(reverse=True)
y

# %%
# raise error
z = [1, 3, 2, 4, 'Alice', 'Bob']
z.sort()

# %%
# lower and upper case sorting problem
m = ['Alice', 'ants', 'Bob', 'badgers', 'Carol', 'cats']
m.sort()
m

# %%
# solve that problem
spam = ['a', 'z', 'A', 'Z']
spam.sort(key=str.lower)
spam

# %% [markdown]
# ## Manipulasi String
#
# ### String Literals
# - \'          Single quote
# - \"          Double quote
# - \t          Tab
# - \n         Newline (line break)
# - \\          Backslash

# %%
print("Hello there!\nHow are you?\nI\'m doing fine.")

# %%
# multi line string
multi_line = """Hello there!
How are you?
I'm fine."""
print(multi_line)

# %%
# raw string => umumnya digunakan untuk regex atau implementasi lain yang bergantung pada keberadaan backslash
print(r'That is Carol\'s cat.')

# %% [markdown]
# ## Operator dan Expression
#
# ### Math Operator

# %%
# addition
3 + 5

# %%
# substraction
3 - 5

# %%
# multiplication
3 * 5

# %%
# power/exponentiation
3 ** 5

# %%
# division
15 / 5

# %%
# Floor Division
17 // 4

# %%
# modulo
15 % 2

# %% [markdown]
# ### Bit Operator

# %%
2 << 2

# %% [markdown]
# - 2 << 2 menghasilkan 8.
# - 2 direpresentasikan sebagai 10 dalam binary.
# - Geser ke kiri sebanyak 2x, menjadi 1000 (tambahkan 0 di belakangnya).
# - 1000 dalam binary bernilai 8 dalam desimal.

# %%
11 >> 1

# %% [markdown]
# - 11 >> 1 menghasilkan 5.
# - 11 direpresentasikan sebagai 1011 dalam binary.
# - Geser ke kanan sebanyak 1x, menjadi 101.
# - 101 dalam binary bernilai 5 dalam desimal.

# %%
5 & 3

# %% [markdown]
# - 5 & 3 menghasilkan 1.
# - Representasi binary 5 adalah 101 dan representasi binary 3 adalah 011.
# - 101 and 011 bernilai 001.
# - 001 dalam desimal adalah 1.

# %%
5 | 3

# %% [markdown]
# - 5 | 3 menghasilkan 7.
# - Representasi binary 5 adalah 101 dan representasi binary 3 adalah 011.
# - 101 or 011 bernilai 111.
# - 111 dalam desimal adalah 7.

# %%
5 ^ 3

# %% [markdown]
# - 5 ^ 3 menghasilkan 6.
# - Representasi binary 5 adalah 101 dan representasi binary 3 adalah 011.
# - 101 xor 011 bernilai 110.
# - 110 dalam desimal adalah 6.

# %%
~5

# %% [markdown]
# - Menjalankan operasi binary invert pada representasi operand.
# - Nilai invert dari x adalah -(x+1), menggunakan metode Two’s Complement
# - ~5 menghasilkan -6.
