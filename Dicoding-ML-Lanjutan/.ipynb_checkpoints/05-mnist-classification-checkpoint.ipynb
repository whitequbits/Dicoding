# %% [markdown]
# # Welcome to MNIST Classification

# %% [markdown]
# ### Import all dependencies

# %%
pip install pydot==1.3.0
# Out:
# Requirement already satisfied: pydot==1.3.0 in /usr/local/anaconda3/lib/python3.7/site-packages (1.3.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/anaconda3/lib/python3.7/site-packages (from pydot==1.3.0) (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz==0.10.1
# Out:
# Requirement already satisfied: graphviz==0.10.1 in /usr/local/anaconda3/lib/python3.7/site-packages (0.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import plot_model
from keras import callbacks

# %% [markdown]
# ### Import Training data

# %%
mnist = tf.keras.datasets.mnist

# %%
(gambar_latih, label_latih), (gambar_testing, label_testing) = mnist.load_data()

# %%
np.set_printoptions(linewidth=200)
plt.imshow(gambar_latih[0])
print(label_latih[0])
# Out:
# 5

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Normalization

# %%
gambar_latih  = gambar_latih / 255.0
gambar_testing = gambar_testing / 255.0

# %% [markdown]
# To Avoid Error ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float)

# %%
gambar_latih, gambar_testing, label_latih, label_testing = gambar_latih.astype('float64'), gambar_testing.astype('float64'), label_latih.astype('float64'), label_testing.astype('float64')

# %% [markdown]
# ### Create the model
#
# 1. 2 Layer with 128 unit and 10 unit of output
# 2. Flatten input into 28x28 array
# 3. Softmax turn logit into probability
# 4. Relu to create linear activation

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)), 
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu), 
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

# %% [markdown]
# ##### Create the loss and optimizer function
#
# 1. Adam Optimizer => replacement optimization algorithm for stochastic gradient descent
# 2. binary cross entropy as loss function => used for multi-class classification
# 3. metrics to benchmark is accuracy

# %%
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plot_model(model, to_file='05-mnist-classification.png')

# %% [markdown]
# ### Create Callback

# %%
class myCallback(callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9):
      print("\nYour Accuracy >90%!")
      self.model.stop_training = True

# %%
callbacks = myCallback()

# %% [markdown]
# ### Fit the model and Save the History

# %% [markdown]
# #### Batch Loading

# %% [markdown]
# - Secara Default: batch_size = 32
# - Berguna untuk mempercepat pelatihan model kita
# - Kita dapat bereksperimen dgn nilai batch size antara 32,64,128

# %%
hist = model.fit(gambar_latih, label_latih, epochs=20, batch_size=128, callbacks=[callbacks])
# Out:
# Epoch 1/20
# 455/469 [============================>.] - ETA: 0s - loss: 0.3575 - accuracy: 0.9013
# Your Accuracy >90%!
# 469/469 [==============================] - 2s 3ms/step - loss: 0.3532 - accuracy: 0.9025

# %% [markdown]
# ### Test Model

# %%
model.evaluate(gambar_testing, label_testing)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1887 - accuracy: 0.9472
# [0.18866418302059174, 0.9472000002861023]

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plot Model Loss

# %%
plt.plot(hist.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper right')
plt.show()

# %% [markdown]
# #### Plot Model Accuracy

# %%
plt.plot(hist.history['accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='lower right')
plt.show()
