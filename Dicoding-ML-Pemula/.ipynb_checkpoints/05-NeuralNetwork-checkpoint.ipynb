# %% [markdown]
# # Neural Network
#
# - model machine learning yang terinspirasi dari cara kerja otak manusia
#
# ## Artificial neural network (ANN)
#
# - ANN merupakan salah satu model ML yang multiguna, powerful, dan memiliki skalabilitas tinggi.
# - semakin banyak jumlah hidden layer dalam sistem, semakin lama jaringan saraf tersebut memproduksi hasil, namun juga semakin kompleks masalah yang dapat diselesaikan.
#
# ![](https://dicodingacademy.blob.core.windows.net/academies/20200430185034b0a0ce9bdafc593bb93812116dfdf710.png)
# ![](https://dicodingacademy.blob.core.windows.net/academies/202004301851078768b29dd102a0ffd6d77009a516990c.png)
# ![](https://dicodingacademy.blob.core.windows.net/academies/20200430185453c061be57e0baa8783ef4446e6ec1d04b.png)
#
# ### Multi Layer Perceptron (MLP)
#
# - Sebuah jaringan saraf yang terdiri dari satu layer input, satu atau lebih hidden layer, dan satu output laye
# - MLP yang memiliki banyak hidden layer disebut juga deep neural network (DNN)
#
# ˜[](https://dicodingacademy.blob.core.windows.net/academies/20200430185956d9f0a66de0a9763d29454d47c33d82a3.png)
#
# ### Back Propagation
#
# - sebuah algoritma untuk melatih MLP
# - teknik yang memungkinkan MLP untuk belajar membuat prediksinya semakin baik.
#
# Cara kerja propagasi balik secara sederhana terdiri dari 3 tahap yaitu:
#
# - Jaringan saraf pada awalnya membuat prediksi
# - Keluaran hasil prediksi kemudian diukur tingkat erornya menggunakan loss function.
# - Hasil eror kemudian dikirim menggunakan propagasi balik agar jaringan saraf dapat menyesuaikan bobot yang meminimalisir eror dengan optimizer.
#
# ![](https://dicodingacademy.blob.core.windows.net/academies/20200430191938b814af53cb0db6aadbcf61beaeb7eaa7.gif)

# %% [markdown]
# ## Convolutional Neural Network (CNN)
#
# <https://cs231n.github.io/convolutional-networks/>
#
# - Sebuah jaringan saraf biasa mengenali gambar berdasarkan piksel-piksel yang terdapat pada gambar
# - Convolutional layer membantu jaringan saraf untuk mengenali objek seperti orang berdasarkan atribut-atributnya.
#
# ![](https://dicodingacademy.blob.core.windows.net/academies/202004301905352425fc2219ac2cf38568dca51c98100c.png)
#
# - jaringan saraf yang menggunakan sebuah layar konvolusi dan max pooling
#
# ![](https://dicodingacademy.blob.core.windows.net/academies/20200430190708902a461c94c542ba9d39b48f5d091c79.png)
